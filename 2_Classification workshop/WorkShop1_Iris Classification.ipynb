# %% [markdown]
# # Workshop 1: Iris classification with kNN
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Step 1. Importing data from .CSV file
#
# ![image.png](attachment:image.png)

# %%
#import pandas package to read the csv file
import pandas as pd

iris = pd._____('_____.csv')
iris[:20]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %% [markdown]
# ### As you can see, the data can be seperated into Features and Label as following:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 2. Data preparation
#
# - The unnecessary column will be removed (as Id).
# - Then, remaining data will be seperated into training and testing sets.
# - For example, 30% of data are keep for testing and 70% for trianing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - drop the unnecessary column

# %%
iris = iris._____(labels=_____,axis=1)
iris[:20]

# %% [markdown]
# - move the values from dataframe data type to Array.

# %%
#creating the array 
array = iris._____

# %% [markdown]
# - define X, y are the features(input) and its labels(target)

# %%
X = array[_____,_____]
y = array[_____,_____]

# print out the example of data for X,y and showing its shape
print(X[0:10,:])
print(y[0:10])
print(X._____, y._____)

# %% [markdown]
# - Now, the process of data seperation for training and testing dataset
# - Let define the 30% for test set and 70% for training set.
# - In Sci-kit learn package, there is the train_test_split function for this process.

# %%
from sklearn.model_selection import train_test_split

_____, _____, _____, _____ = train_test_split(X, y, test_size = _____, random_state = 7)

# %% [markdown]
# - show the example of data shapes

# %%
print(X_train[0:10])
print(y_train[0:10])
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# %% [markdown]
# ##  Step 3. Creating Model and Testing
# - Now, the prepared data will be trained as the k-NN technique

# %%
from sklearn.neighbors import KNeighborsClassifier

#create model
knn = KNeighborsClassifier(n_neighbors=_____)

#train the model
knn._____(_____, _____)

# %% [markdown]
# - Then, we can apply the model for testing process
# - We will use the test set (X_test) for prediction.

# %%
#prediction
y_predict = knn._____(_____)

# %% [markdown]
# - Showing the output as dataFrame comparing to y_predict

# %%
#creating the Dataframe of y_predict and y_test
df1 = pd.DataFrame(y_predict,columns=['y_predict'])
df1['y_test'] = pd.DataFrame(y_test)
df1

# %% [markdown]
# ##  Step 4. Evaluating the model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### - We can implement in sklearn as below

# %%
from sklearn.metrics import accuracy_score

print("Accuracy: %s\n" % _____(_____, _____))

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### - We can find the confusion matrix by sklearn package as below

# %%
from sklearn.metrics import confusion_matrix

print("Confusion Matrix\n %s \n" 
      % confusion_matrix(_____, _____, labels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']))

# %% [markdown]
# ### - We can also show classification report for model evaluation as below

# %%
from sklearn.metrics import classification_report
print("Classification Report\n %s \n" % classification_report(_____, _____))

# %% [markdown]
# # Step 5 - (after got the model). Prediction with unknown data
# * need to input data as **[SepalLengthCm,	SepalWidthCm,	PetalLengthCm,	PetalWidthCm]**

# %%
new_input = [ [_____] ] 
answer = knn._____(_____)

print("this is a", answer[0])
